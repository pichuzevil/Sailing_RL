# %% [markdown]
# # Testing Agent Validity
#
# This notebook provides a quick sanity check that your agent implementation meets the required interface specifications for the Sailing Challenge. It does not test performance - only that your agent can be loaded and will return valid actions.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary validation tools:

# %%
import sys
import os
import numpy as np

# Add the src directory to the path
sys.path.append(os.path.abspath('../src'))
sys.path.append(os.path.abspath('..'))

# Import the agent validation module
from src.test_agent_validity import validate_agent

# %% [markdown]
# ## Agent Requirements
#
# Your agent must:
#
# 1. **Inherit from BaseAgent** (`from src.agents.base_agent import BaseAgent`)
# 2. **Implement these methods**:
#    - `act(observation)`: Return an action (0-8) based on the observation
#    - `reset()`: Reset the agent's internal state
#    - `seed(seed)`: Set the random seed for reproducibility
#
# Actions must be integers in the range 0-8 (0-7 for movement directions, 8 to stay in place).

# %%
def print_validation_results(results):
    """Print validation results in a readable format."""
    print("\n" + "="*50)
    print(f"Agent: {results['agent_name']}")
    print("="*50)
    
    if results['valid']:
        print("✅ VALID: Agent implements all required methods and returns valid actions.")
    else:
        print("❌ INVALID: Agent validation failed. See errors below.")
        
    if results['errors']:
        print("\nErrors:")
        for i, error in enumerate(results['errors'], 1):
            print(f"{i}. {error}")
    
    if results['warnings']:
        print("\nWarnings (these won't prevent submission):")
        for i, warning in enumerate(results['warnings'], 1):
            print(f"{i}. {warning}")
    
    print("="*50)

# First, test the example agent to show how validation works
example_agent_path = "../src/agents/agent_astar.py"
print("Testing example agent...")
results = validate_agent(example_agent_path)
print_validation_results(results)
# Out:
# Testing example agent...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 27
#      23
#      24 # First, test the example agent to show how validation works
#      25 example_agent_path = "../src/agents/agent_astar.py"
#      26 print("Testing example agent...")
# ---> 27 results = validate_agent(example_agent_path)
#      28 print_validation_results(results)
#
# File ~/dev/ENSAE/S2/RL/Sailing_RL/src/test_agent_validity.py:272, in validate_agent(filepath)
#     269     return results
#     271 # Step 4: Test agent actions
# --> 272 action_issues = test_agent_actions(agent_instance)
#     273 if action_issues:
#     274     results['errors'].extend(action_issues)
#
# File ~/dev/ENSAE/S2/RL/Sailing_RL/src/test_agent_validity.py:192, in test_agent_actions(agent_instance)
#     189 for _ in range(10):
#     190     try:
#     191         # Get action from agent
# --> 192         action = agent_instance.act(observation)
#     194         # Check if action is an integer
#     195         if not isinstance(action, (int, np.integer)):
#
# File ~/dev/ENSAE/S2/RL/Sailing_RL/notebooks/../src/agents/agent_astar.py:156, in MyAgent.act(self, observation)
#     153 # 2. Receding Horizon Logic
#     154 # We re-plan if we are out of actions OR every N steps to correct for 0.01 deg jitter
#     155 if not self.planned_path or self.steps_since_plan >= self.replan_frequency:
# --> 156     self.planned_path = self.plan_path(pos, vel, wind)
#     157     self.steps_since_plan = 0
#     159 if self.planned_path:
#
# File ~/dev/ENSAE/S2/RL/Sailing_RL/notebooks/../src/agents/agent_astar.py:68, in MyAgent.plan_path(self, start_pos, start_vel, start_wind)
#      65 f, t, x, y, vx, vy, path = heapq.heappop(pq)
#      67 # Goal reached check (matches reached_goal < 1.5 in env)
# ---> 68 if np.linalg.norm(np.array([x, y]) - self.goal_pos) < 1.5:
#      69     return path
#      71 if t > 55: continue # Prune if we exceed reasonable performance
#
# File ~/dev/ENSAE/S2/RL/Sailing_RL/venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2594, in _norm_dispatcher(x, ord, axis, keepdims)
#    2590     result = op(svd(y, compute_uv=False), axis=-1, initial=initial)
#    2591     return result
# -> 2594 def _norm_dispatcher(x, ord=None, axis=None, keepdims=None):
#    2595     return (x,)
#    2598 @array_function_dispatch(_norm_dispatcher)
#    2599 def norm(x, ord=None, axis=None, keepdims=False):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Validate Your Agent
#
# Now validate your own agent implementation:
#
# 1. Set the path to your agent file below
# 2. Run the cell to check if your agent meets the requirements
# 3. Fix any errors and rerun until validation passes

# %%
# Replace this with the path to your agent implementation
# your_agent_path = "../your_agent.py"  # Change this!
your_agent_path = "../src/agents/agent_trained_example.py"

try:
    # Validate your agent
    results = validate_agent(your_agent_path)
    print_validation_results(results)
    
except FileNotFoundError:
    print(f"❌ File not found: {your_agent_path}")
    print("Please provide the correct path to your agent implementation.")
except Exception as e:
    print(f"❌ Error: {str(e)}")
    print("Make sure your file has valid Python syntax and can be imported.")
# Out:
# ==================================================
# Agent: QLearningTrainedAgent
# ==================================================
# ✅ VALID: Agent implements all required methods and returns valid actions.
#
# Warnings (these won't prevent submission):
# 1. Agent does not implement save() method
# 2. Agent does not implement load() method
# ==================================================

# %% [markdown]
# ## Command-Line Usage
#
# You can also validate your agent from the command line:
#
# ```bash
# cd src
# python3 test_agent_validity.py agents/agent_super_naive.py
# ```
#
# ### Sample Output
#
# Here's what the output looks like for a valid agent:
# ```bash
# Agent validation results for: src/agents/agent_super_naive.py
# Agent name: SuperNaiveAgent
# Valid: True
# Validation successful! The agent meets all requirements.
# ```
#
# And here's an example of validation failure output:
# ```bash
# Agent validation results for: path/to/invalid_agent.py
# Agent name: InvalidAgent
# Valid: False
# Errors:
# Agent returned out-of-range action: 10 (valid range: 0-8)
# Method reset is not callable
# Validation failed. Please fix the errors and try again.
# ```
#
# This command-line tool provides a quick way to check if your agent implementation meets the basic requirements before running a full evaluation.

# %% [markdown]
# ## Next Steps
#
# If your agent passes validation:
#
# 1. It can be properly loaded and evaluated in the challenge environment
# 2. It will return valid actions that the environment can process
# 3. It's ready for submission
#
# For comprehensive performance evaluation, use the `evaluate_agent.ipynb` notebook, which tests your agent across different training wind scenarios.
